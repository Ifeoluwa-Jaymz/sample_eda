# %%
import pandas as pd
import numpy as np
from datetime import datetime, timedelta
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel(r'C:/Users/ACER/Downloads/acoustic_features.xlsx')

# %%
df1 = df.copy()

# %%
df1.head()
# Out:
#                   song_id  duration_ms  key  mode  time_signature  \
# 0  3e9HZxeyfWwjeyPAMmWSSQ       207320    1     1               4
# 1  5p7ujcrUXASCNwRaWNHR1C       201661    6     1               4
# 2  2xLMifQCjDGFmkHkpNLD9h       312820    8     1               4
# 3  3KkXRkHbMCARz0aVfEt68P       158040    2     1               4
# 4  1rqqCSm0Qe4I9rUvWncaom       190947    5     1               4
#
#    acousticness  danceability  energy  instrumentalness  liveness  loudness  \
# 0       0.22900         0.717   0.653          0.000000    0.1010    -5.634
# 1       0.29700         0.752   0.488          0.000009    0.0936    -7.050
# 2       0.00513         0.834   0.730          0.000000    0.1240    -3.714
# 3       0.55600         0.760   0.479          0.000000    0.0703    -5.574
# 4       0.19300         0.579   0.904          0.000000    0.0640    -2.729
#
#    speechiness  valence    tempo
# 0       0.0658    0.412  106.966
# 1       0.0705    0.533  136.041
# 2       0.2220    0.446  155.008
# 3       0.0466    0.913   89.911
# 4       0.0618    0.681   82.014

# %%
df1.shape
# Out:
# (20405, 14)

# %%
df1.size
# Out:
# 285670

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20405 entries, 0 to 20404
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   song_id           20405 non-null  object
#  1   duration_ms       20405 non-null  int64
#  2   key               20405 non-null  int64
#  3   mode              20405 non-null  int64
#  4   time_signature    20405 non-null  int64
#  5   acousticness      20405 non-null  float64
#  6   danceability      20405 non-null  float64
#  7   energy            20405 non-null  float64
#  8   instrumentalness  20405 non-null  float64
#  9   liveness          20405 non-null  float64
#  10  loudness          20405 non-null  float64
#  11  speechiness       20405 non-null  float64
#  12  valence           20405 non-null  float64
#  13  tempo             20405 non-null  float64
# dtypes: float64(9), int64(4), object(1)
# memory usage: 2.2+ MB

# %%
df1.describe(include='all')
# Out:
#                        song_id   duration_ms           key          mode  \
# count                    20405  2.040500e+04  20405.000000  20405.000000
# unique                   20405           NaN           NaN           NaN
# top     3e9HZxeyfWwjeyPAMmWSSQ           NaN           NaN           NaN
# freq                         1           NaN           NaN           NaN
# mean                       NaN  2.295437e+05      5.224651      0.727028
# std                        NaN  6.705696e+04      3.567111      0.445498
# min                        NaN  2.460400e+04      0.000000      0.000000
# 25%                        NaN  1.864930e+05      2.000000      0.000000
# 50%                        NaN  2.230260e+05      5.000000      1.000000
# 75%                        NaN  2.596930e+05      8.000000      1.000000
# max                        NaN  1.561133e+06     11.000000      1.000000
#
#         time_signature  acousticness  danceability        energy  \
# count     20405.000000  20405.000000  20405.000000  20405.000000
# unique             NaN           NaN           NaN           NaN
# top                NaN           NaN           NaN           NaN
# freq               NaN           NaN           NaN           NaN
# mean          3.943592      0.265201      0.600342      0.625056
# std           0.289162      0.264370      0.150627      0.197120
# min           0.000000      0.000001      0.000000      0.006640
# 25%           4.000000      0.039200      0.502000      0.481000
# 50%           4.000000      0.169000      0.608000      0.640000
# 75%           4.000000      0.440000      0.706000      0.783000
# max           5.000000      0.995000      0.988000      0.998000
#
#         instrumentalness      liveness      loudness   speechiness  \
# count       20405.000000  20405.000000  20405.000000  20405.000000
# unique               NaN           NaN           NaN           NaN
# top                  NaN           NaN           NaN           NaN
# freq                 NaN           NaN           NaN           NaN
# mean            0.047546      0.192335     -8.845186      0.067537
# std             0.168418      0.164047      3.593048      0.074369
# min             0.000000      0.013000    -30.896000      0.000000
# 25%             0.000000      0.088300    -11.217000      0.031900
# 50%             0.000010      0.129000     -8.471000      0.040400
# 75%             0.001110      0.249000     -6.051000      0.063000
# max             0.985000      0.997000      3.440000      0.950000
#
#              valence         tempo
# count   20405.000000  20405.000000
# unique           NaN           NaN
# top              NaN           NaN
# freq             NaN           NaN
# mean        0.607777    120.313409
# std         0.236527     27.683465
# min         0.000000      0.000000
# 25%         0.427000     99.735000
# 50%         0.632000    118.952000
# 75%         0.804000    135.903000
# max         1.000000    231.028000

# %%
df1.isna().sum()
# Out:
# song_id             0
# duration_ms         0
# key                 0
# mode                0
# time_signature      0
# acousticness        0
# danceability        0
# energy              0
# instrumentalness    0
# liveness            0
# loudness            0
# speechiness         0
# valence             0
# tempo               0
# dtype: int64

# %%
df1['duration_ms'].value_counts()
# Out:
# 244133    10
# 201867     9
# 216067     9
# 224000     9
# 228867     8
#           ..
# 284280     1
# 297600     1
# 257946     1
# 308872     1
# 177136     1
# Name: duration_ms, Length: 12659, dtype: int64

# %%
df1['duration_ms']= pd.to_datetime(df1['duration_ms'])

# %%
df1.head()
# Out:
#                   song_id                   duration_ms  key  mode  \
# 0  3e9HZxeyfWwjeyPAMmWSSQ 1970-01-01 00:00:00.000207320    1     1
# 1  5p7ujcrUXASCNwRaWNHR1C 1970-01-01 00:00:00.000201661    6     1
# 2  2xLMifQCjDGFmkHkpNLD9h 1970-01-01 00:00:00.000312820    8     1
# 3  3KkXRkHbMCARz0aVfEt68P 1970-01-01 00:00:00.000158040    2     1
# 4  1rqqCSm0Qe4I9rUvWncaom 1970-01-01 00:00:00.000190947    5     1
#
#    time_signature  acousticness  danceability  energy  instrumentalness  \
# 0               4       0.22900         0.717   0.653          0.000000
# 1               4       0.29700         0.752   0.488          0.000009
# 2               4       0.00513         0.834   0.730          0.000000
# 3               4       0.55600         0.760   0.479          0.000000
# 4               4       0.19300         0.579   0.904          0.000000
#
#    liveness  loudness  speechiness  valence    tempo
# 0    0.1010    -5.634       0.0658    0.412  106.966
# 1    0.0936    -7.050       0.0705    0.533  136.041
# 2    0.1240    -3.714       0.2220    0.446  155.008
# 3    0.0703    -5.574       0.0466    0.913   89.911
# 4    0.0640    -2.729       0.0618    0.681   82.014

# %%
df1["duration_ms"].min(), df1["duration_ms"].max()
# Out:
# (Timestamp('1970-01-01 00:00:00.000024604'),
#  Timestamp('1970-01-01 00:00:00.001561133'))

# %%
df1["duration_ms"].max() - df1["duration_ms"].min()
# Out:
# Timedelta('0 days 00:00:00.001536529')

# %%
#conveting duation in minute to minutes

df1["duration_in_min"] = df1["duration_ms"].dt.strftime("%H:%M:%S.%f")
df1['duration_in_min'] = df1['duration_s'].astype(str)
df1['duration_in_min'] = df1['duration_in_min'].str.slice(-6)
df1['duration_in_min'] = df1['duration_in_min'].astype(int)
df1['duration_in_min'] = df1['duration_in_min'].div(60).round(2)

# %%
df1['duration_in_min'].nunique()
# Out:
# 502

# %%
avg = df1[df1['duration_in_min']>=2]
avg
# Out:
#                       song_id                   duration_ms  key  mode  \
# 0      3e9HZxeyfWwjeyPAMmWSSQ 1970-01-01 00:00:00.000207320    1     1
# 1      5p7ujcrUXASCNwRaWNHR1C 1970-01-01 00:00:00.000201661    6     1
# 2      2xLMifQCjDGFmkHkpNLD9h 1970-01-01 00:00:00.000312820    8     1
# 3      3KkXRkHbMCARz0aVfEt68P 1970-01-01 00:00:00.000158040    2     1
# 4      1rqqCSm0Qe4I9rUvWncaom 1970-01-01 00:00:00.000190947    5     1
# ...                       ...                           ...  ...   ...
# 20400  0yZsBLZVU2HTMlMqYvWevJ 1970-01-01 00:00:00.000133744    5     1
# 20401  30342v7I9sUoNC0Djnu1mW 1970-01-01 00:00:00.000125293    1     1
# 20402  5rkgbGIOTBGlKTAawWb06X 1970-01-01 00:00:00.000139400    4     0
# 20403  2MVPsa4S4r7Ii5lMh85E03 1970-01-01 00:00:00.000131333    9     1
# 20404  7wGbzk3aeGSpnsK2AQ7vzA 1970-01-01 00:00:00.000177136    5     0
#
#        time_signature  acousticness  danceability  energy  instrumentalness  \
# 0                   4       0.22900         0.717   0.653          0.000000
# 1                   4       0.29700         0.752   0.488          0.000009
# 2                   4       0.00513         0.834   0.730          0.000000
# 3                   4       0.55600         0.760   0.479          0.000000
# 4                   4       0.19300         0.579   0.904          0.000000
# ...               ...           ...           ...     ...               ...
# 20400               4       0.38700         0.453   0.647          0.000000
# 20401               4       0.64700         0.576   0.542          0.000000
# 20402               4       0.14400         0.300   0.743          0.000000
# 20403               4       0.79100         0.488   0.830          0.000728
# 20404               4       0.86300         0.725   0.616          0.918000
#
#        liveness  loudness  speechiness  valence    tempo       duration_s  \
# 0        0.1010    -5.634       0.0658    0.412  106.966  00:00:00.000207
# 1        0.0936    -7.050       0.0705    0.533  136.041  00:00:00.000201
# 2        0.1240    -3.714       0.2220    0.446  155.008  00:00:00.000312
# 3        0.0703    -5.574       0.0466    0.913   89.911  00:00:00.000158
# 4        0.0640    -2.729       0.0618    0.681   82.014  00:00:00.000190
# ...         ...       ...          ...      ...      ...              ...
# 20400    0.4510    -7.985       0.0277    0.728   71.357  00:00:00.000133
# 20401    0.1730    -8.371       0.0276    0.508  104.083  00:00:00.000125
# 20402    0.3850   -10.005       0.0393    0.952  154.180  00:00:00.000139
# 20403    0.1550    -4.487       0.0402    0.950  181.869  00:00:00.000131
# 20404    0.1440    -3.299       0.0304    0.594  125.817  00:00:00.000177
#
#               duration              dur     s  duration_in_min
# 0      00:00:00.000207              NaN  3.45             3.45
# 1      00:00:00.000201              NaN  3.35             3.35
# 2      00:00:00.000312              NaN  5.20             5.20
# 3      00:00:00.000158              NaN  2.63             2.63
# 4      00:00:00.000190              NaN  3.17             3.17
# ...                ...              ...   ...              ...
# 20400  00:00:00.000133  00:00:00.000133  2.22             2.22
# 20401  00:00:00.000125  00:00:00.000125  2.08             2.08
# 20402  00:00:00.000139  00:00:00.000139  2.32             2.32
# 20403  00:00:00.000131  00:00:00.000131  2.18             2.18
# 20404  00:00:00.000177  00:00:00.000177  2.95             2.95
#
# [20246 rows x 19 columns]

# %%
avg_less = df1[df1['duration_in_min']<2]
avg_less
# Out:
#                       song_id                   duration_ms  key  mode  \
# 22     2uFaJJtFpPDc5Pa95XzTvg 1970-01-01 00:00:00.000117147    1     1
# 32     75nEUfYzeskPFRBQk5BvCg 1970-01-01 00:00:00.000087016   11     1
# 37     4CH66Rxcjcj3VBHwmIBj4T 1970-01-01 00:00:00.000094246    5     0
# 62     7uqcLJFlSYjVPLUz1vPxkY 1970-01-01 00:00:00.000108035    0     0
# 67     4KpKyRFwN0gcwj58Uqjv7q 1970-01-01 00:00:00.000085124    5     1
# ...                       ...                           ...  ...   ...
# 19988  3BBrBOfTuMwVmQToKWQxZx 1970-01-01 00:00:00.000110920    4     1
# 20001  5p8usctaD0x2lprysDwstM 1970-01-01 00:00:00.000088573    4     0
# 20227  0tVDfAiHDgvRyXuVike1Ju 1970-01-01 00:00:00.000029688   11     1
# 20282  3WTSy94Lv7udWMIpRtgPyH 1970-01-01 00:00:00.000024604    4     0
# 20373  2L3uJj4ha9Y5QCZUkld5ah 1970-01-01 00:00:00.000092667    2     1
#
#        time_signature  acousticness  danceability  energy  instrumentalness  \
# 22                  4        0.9120         0.452   0.240          0.000002
# 32                  4        0.5670         0.877   0.477          0.000000
# 37                  4        0.0643         0.780   0.492          0.031300
# 62                  4        0.7950         0.712   0.374          0.000000
# 67                  4        0.1340         0.557   0.338          0.001840
# ...               ...           ...           ...     ...               ...
# 19988               4        0.9500         0.526   0.434          0.145000
# 20001               4        0.3980         0.647   0.761          0.000000
# 20227               4        0.0661         0.709   0.504          0.000000
# 20282               4        0.0156         0.437   0.979          0.979000
# 20373               4        0.0914         0.480   0.868          0.000008
#
#        liveness  loudness  speechiness  valence    tempo       duration_s  \
# 22        0.175   -14.014       0.0351    0.701  134.005  00:00:00.000117
# 32        0.114    -5.391       0.0623    0.688   95.024  00:00:00.000087
# 37        0.174    -3.400       0.0671    0.374  143.983  00:00:00.000094
# 62        0.187   -10.215       0.5110    0.779  133.952  00:00:00.000108
# 67        0.140    -9.892       0.0257    0.689  140.935  00:00:00.000085
# ...         ...       ...          ...      ...      ...              ...
# 19988     0.259   -12.828       0.0529    0.742  145.434  00:00:00.000110
# 20001     0.345    -9.571       0.0505    0.961  107.059  00:00:00.000088
# 20227     0.360   -17.387       0.2020    0.942  142.544  00:00:00.000029
# 20282     0.961   -11.999       0.0556    0.264  116.346  00:00:00.000024
# 20373     0.331    -4.753       0.0459    0.695  128.854  00:00:00.000092
#
#               duration              dur     s  duration_in_min
# 22     00:00:00.000117  00:00:00.000117  1.95             1.95
# 32     00:00:00.000087  00:00:00.000087  1.45             1.45
# 37     00:00:00.000094  00:00:00.000094  1.57             1.57
# 62     00:00:00.000108  00:00:00.000108  1.80             1.80
# 67     00:00:00.000085  00:00:00.000085  1.42             1.42
# ...                ...              ...   ...              ...
# 19988  00:00:00.000110  00:00:00.000110  1.83             1.83
# 20001  00:00:00.000088  00:00:00.000088  1.47             1.47
# 20227  00:00:00.000029  00:00:00.000029  0.48             0.48
# 20282  00:00:00.000024  00:00:00.000024  0.40             0.40
# 20373  00:00:00.000092  00:00:00.000092  1.53             1.53
#
# [159 rows x 19 columns]

# %%
# What is the average liveliness found in music greater than 2 and half minutes
avg_cc = df1[df1['duration_in_min']>=2.5]['liveness'].mean()
print('Avg. cc tip:', avg_cc)


# What is the average tip for liveliness found in music less than 2 and half minutes?
avg_cc_l = df1[df1['duration_in_min']<2.5]['liveness'].mean()
print('Avg. cash tip:', avg_cc_l)
# Out:
# Avg. cc tip: 0.19111867581113162
# Avg. cash tip: 0.20823448275862072

# %%
df1.groupby(['time_signature']).mean(numeric_only=True)[['duration_in_min', 'liveness']]
# Out:
#                 duration_in_min  liveness
# time_signature
# 0                      2.450000  0.198000
# 1                      3.523607  0.241602
# 3                      3.550931  0.193259
# 4                      3.833601  0.191996
# 5                      3.842645  0.212809

# %%
df1.head()
# Out:
#                   song_id                   duration_ms  key  mode  \
# 0  3e9HZxeyfWwjeyPAMmWSSQ 1970-01-01 00:00:00.000207320    1     1
# 1  5p7ujcrUXASCNwRaWNHR1C 1970-01-01 00:00:00.000201661    6     1
# 2  2xLMifQCjDGFmkHkpNLD9h 1970-01-01 00:00:00.000312820    8     1
# 3  3KkXRkHbMCARz0aVfEt68P 1970-01-01 00:00:00.000158040    2     1
# 4  1rqqCSm0Qe4I9rUvWncaom 1970-01-01 00:00:00.000190947    5     1
#
#    time_signature  acousticness  danceability  energy  instrumentalness  \
# 0               4       0.22900         0.717   0.653          0.000000
# 1               4       0.29700         0.752   0.488          0.000009
# 2               4       0.00513         0.834   0.730          0.000000
# 3               4       0.55600         0.760   0.479          0.000000
# 4               4       0.19300         0.579   0.904          0.000000
#
#    liveness  loudness  speechiness  valence    tempo       duration_s
# 0    0.1010    -5.634       0.0658    0.412  106.966  00:00:00.000207
# 1    0.0936    -7.050       0.0705    0.533  136.041  00:00:00.000201
# 2    0.1240    -3.714       0.2220    0.446  155.008  00:00:00.000312
# 3    0.0703    -5.574       0.0466    0.913   89.911  00:00:00.000158
# 4    0.0640    -2.729       0.0618    0.681   82.014  00:00:00.000190

# %%
df1['duration_in_min'] = df1['duration_s'].astype(str)

# %%
df1.dtypes
# Out:
# song_id                     object
# duration_ms         datetime64[ns]
# key                          int64
# mode                         int64
# time_signature               int64
# acousticness               float64
# danceability               float64
# energy                     float64
# instrumentalness           float64
# liveness                   float64
# loudness                   float64
# speechiness                float64
# valence                    float64
# tempo                      float64
# duration_s                  object
# duration                    object
# dur                         object
# s                          float64
# duration_in_min            float64
# dtype: object

# %%
df['instrumentalness'].nunique()
# Out:
# 4345

# %%
df['valence'].nunique()
# Out:
# 1071

# %%
df1['tempo'].nunique()
# Out:
# 17805

# %%
df1['key'].nunique()
# Out:
# 12

# %%
df1['key'].value_counts()
# Out:
# 0     2578
# 7     2371
# 2     2170
# 9     2163
# 5     1805
# 1     1778
# 4     1635
# 11    1462
# 10    1421
# 6     1208
# 8     1176
# 3      638
# Name: key, dtype: int64

# %%
df1['mode'].nunique()
# Out:
# 2

# %%
df1['mode'].value_counts()
# Out:
# 1    14835
# 0     5570
# Name: mode, dtype: int64

# %%
df1['time_signature'].nunique()
# Out:
# 5

# %%
df1['time_signature'].value_counts()
# Out:
# 4    19137
# 3     1085
# 5      121
# 1       61
# 0        1
# Name: time_signature, dtype: int64

# %%
df1['acousticness'].nunique()
# Out:
# 3052

# %%
df1['danceability'].nunique()
# Out:
# 828

# %%
avg_cc_tip = df[df['mode']==1]['liveness']#.mean()
#print('Avg. cc tip:', avg_cc_tip)
avg_cc_tip.max()
# Out:
# 0.997

# %%
avg_cc_ti = df[df['mode']==0]['liveness']
avg_cc_ti.max()
# Out:
# 0.993

# %%
df_key = df.groupby('key')[['liveness']].sum()
df_key
# Out:
#      liveness
# key
# 0    511.5362
# 1    313.1252
# 2    421.4294
# 3    114.3085
# 4    339.7960
# 5    354.0759
# 6    228.0083
# 7    473.1225
# 8    206.1329
# 9    409.2464
# 10   268.1702
# 11   285.6430

# %%
pivot_key = df1.pivot_table(index=['key'],
					values=['liveness'],
					aggfunc='sum')
print(pivot_key)
# Out:
#      liveness
# key
# 0    511.5362
# 1    313.1252
# 2    421.4294
# 3    114.3085
# 4    339.7960
# 5    354.0759
# 6    228.0083
# 7    473.1225
# 8    206.1329
# 9    409.2464
# 10   268.1702
# 11   285.6430

# %%
plt.figure(figsize=(6,5))
ax = sns.barplot(x=pivot_key.index, y=pivot_key['liveness'])
plt.title('Liveness by key', fontsize=16);

# %%
total_amount_day = df.groupby('mode')[['liveness']].sum()
total_amount_day
# Out:
#        liveness
# mode
# 0     1055.9285
# 1     2868.6660

# %%
pivot_mode = df1.pivot_table(index=['mode'],
					values=['liveness'],
					aggfunc='sum')
print(pivot_mode)
# Out:
#        liveness
# mode
# 0     1055.9285
# 1     2868.6660

# %%
plt.figure(figsize=(6,5))
ax = sns.barplot(x=pivot_mode.index, y=pivot_mode['liveness'])
plt.title('Liveness by mode', fontsize=16);

# %%
#time = ['simple', 'compound ', 'complex ', 'mixed ', 'additive ']
dftime = df.groupby('time_signature').sum()[['liveness']]
#dftime = dftime.reindex(index=time)
dftime
# Out:
# C:\Users\ACER\AppData\Local\Temp\ipykernel_1092\775452695.py:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   dftime = df.groupby('time_signature').sum()[['liveness']]
#                  liveness
# time_signature
# 0                  0.1980
# 1                 14.7377
# 3                209.6856
# 4               3674.2233
# 5                 25.7499

# %%
pivot = df1.pivot_table(index=['time_signature'],
					values=['liveness'],
					aggfunc='sum')
print(pivot)
# Out:
#                  liveness
# time_signature
# 0                  0.1980
# 1                 14.7377
# 3                209.6856
# 4               3674.2233
# 5                 25.7499

# %%
plt.figure(figsize=(6,5))
ax = sns.barplot(x=pivot.index, y=pivot['liveness'])
plt.title('Liveness by time signature', fontsize=16);

# %%
pivot['liveness']
# Out:
# time_signature
# 0       0.1980
# 1      14.7377
# 3     209.6856
# 4    3674.2233
# 5      25.7499
# Name: liveness, dtype: float64
